# %%
#Dependency importation
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset
df = pd.read_csv("movies.csv")
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# 9994     \nAdventure, Drama, Fantasy                 NaN
# 9995  \nAnimation, Action, Adventure                 NaN
# 9996            \nDocumentary, Sport                 NaN
# 9997     \nAdventure, Drama, Fantasy                 NaN
# 9998     \nAdventure, Drama, Fantasy                 NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 9994   NaN
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
#
# [9999 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
df.describe()
# Out:
#             RATING      RunTime
# count  8179.000000  7041.000000
# mean      6.921176    68.688539
# std       1.220232    47.258056
# min       1.100000     1.000000
# 25%       6.200000    36.000000
# 50%       7.100000    60.000000
# 75%       7.800000    95.000000
# max       9.900000   853.000000

# %%
# See if there are null values in our dataframe
df.isna().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %% [markdown]
# We can see that our dataframe contains 6 columns having null values.

# %% [markdown]
# #### YEAR COLUMN

# %%
#defining the function to extract the date 
def extract_years(year_str):
    if pd.isna(year_str):
        return None, None  # Return None for NaN values
    
    # Removing any leading extra characters which is not the year
    new_str = re.sub(r"^[^(]*", "", year_str)
    
    # Extract years from the new string containing no extra character
    years = re.findall(r"\d{4}", new_str)

    if len(years) == 0:
        return None, None
    elif len(years) == 1:
        return years[0], None if '–' in new_str else years[0]
    else:
        return years[0], years[-1]

# Apply the function to the 'YEAR' column and create new columns
df['START_YEAR'], df['END_YEAR'] = zip(*df['YEAR'].apply(extract_years))
df
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# 9994     \nAdventure, Drama, Fantasy                 NaN
# 9995  \nAnimation, Action, Adventure                 NaN
# 9996            \nDocumentary, Sport                 NaN
# 9997     \nAdventure, Drama, Fantasy                 NaN
# 9998     \nAdventure, Drama, Fantasy                 NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     None
# 2      NaN       2010     2022
# 3      NaN       2013     None
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     None
# 9995   NaN       2021     None
# 9996   NaN       2022     None
# 9997   NaN       2021     None
# 9998   NaN       2021     None
#
# [9999 rows x 11 columns]

# %%
#We drop the column YEAR
df = df.drop("YEAR", axis=1)

# %%
df.isna().sum()
# Out:
# MOVIES           0
# GENRE           80
# RATING        1820
# ONE-LINE         0
# STARS            0
# VOTES         1820
# RunTime       2958
# Gross         9539
# START_YEAR     748
# END_YEAR      3928
# dtype: int64

# %% [markdown]
# Our new columns START_YEAR and End_Year have Nan values let's try to manage them

# %%
#1-START_YEAR
df["START_YEAR"].unique()
# Out:
# array(['2021', '2010', '2013', '2020', '2006', '2019', '2016', '2011',
#        '2005', '2008', '2017', '1994', '2014', '2015', '2003', '2009',
#        '2018', '1987', '2012', '2007', '2000', '1993', '1999', '2001',
#        '1997', '1989', '1975', '1995', '1984', '1998', '1966', '1990',
#        '2002', '1976', '1978', '2022', '1982', '1968', '2004', '1996',
#        '1971', '1980', '1962', '1991', '1960', '1988', '1969', '1961',
#        '1979', '1956', '1983', None, '1986', '1967', '1974', '1992',
#        '1958', '1932', '1941', '1950', '1946', '1981', '1952', '1957',
#        '1954', '1955', '1948', '1947', '1977', '2023', '1945', '1953',
#        '1985', '1973', '1972', '1965', '1944', '1933', '1938'],
#       dtype=object)

# %%
#Let us replace the Nan values by the most occuring year :  mode
df["START_YEAR"].mode()
# Out:
# 0    2020
# Name: START_YEAR, dtype: object

# %%
df["START_YEAR"].fillna("2020", inplace=True)
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# 9994     \nAdventure, Drama, Fantasy                 NaN
# 9995  \nAnimation, Action, Adventure                 NaN
# 9996            \nDocumentary, Sport                 NaN
# 9997     \nAdventure, Drama, Fantasy                 NaN
# 9998     \nAdventure, Drama, Fantasy                 NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     None
# 2      NaN       2010     2022
# 3      NaN       2013     None
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     None
# 9995   NaN       2021     None
# 9996   NaN       2022     None
# 9997   NaN       2021     None
# 9998   NaN       2021     None
#
# [9999 rows x 10 columns]

# %%
df["START_YEAR"].isna().sum()
# Out:
# 0

# %%
#End Year
df["END_YEAR"].unique()
# Out:
# array(['2021', None, '2022', '2013', '2004', '2020', '2015', '2019',
#        '2014', '2018', '2017', '1994', '2007', '1993', '2016', '2012',
#        '2001', '1999', '1998', '1975', '2008', '2006', '1996', '2000',
#        '2003', '1969', '1991', '1995', '2002', '1976', '1978', '2005',
#        '1968', '2010', '2011', '1971', '1989', '1997', '1980', '2009',
#        '1962', '1984', '1960', '1988', '1987', '1961', '1979', '1956',
#        '1983', '1990', '1986', '1966', '1967', '1974', '1992', '1958',
#        '1932', '1941', '1950', '1946', '1952', '1957', '1954', '1982',
#        '1955', '1948', '1947', '1977', '2023', '1945', '1953', '1985',
#        '1973', '1972', '1965', '1944', '1933', '1938'], dtype=object)

# %%
#We will replace the Nan of the end year by the highest year in the list which is 2023
df["END_YEAR"].fillna("2023", inplace = True)
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 4            \nAction, Crime, Horror                 NaN
# ...                                          ...     ...
# 9994     \nAdventure, Drama, Fantasy                 NaN
# 9995  \nAnimation, Action, Adventure                 NaN
# 9996            \nDocumentary, Sport                 NaN
# 9997     \nAdventure, Drama, Fantasy                 NaN
# 9998     \nAdventure, Drama, Fantasy                 NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df["END_YEAR"].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# MOVIES           0
# GENRE           80
# RATING        1820
# ONE-LINE         0
# STARS            0
# VOTES         1820
# RunTime       2958
# Gross         9539
# START_YEAR       0
# END_YEAR         0
# dtype: int64

# %% [markdown]
# #### COLUMN GENRE

# %%
df["GENRE"]
# Out:
# 0           \nAction, Horror, Thriller
# 1       \nAnimation, Action, Adventure
# 2            \nDrama, Horror, Thriller
# 3       \nAnimation, Adventure, Comedy
# 4              \nAction, Crime, Horror
#                            ...
# 9994       \nAdventure, Drama, Fantasy
# 9995    \nAnimation, Action, Adventure
# 9996              \nDocumentary, Sport
# 9997       \nAdventure, Drama, Fantasy
# 9998       \nAdventure, Drama, Fantasy
# Name: GENRE, Length: 9999, dtype: object

# %%
#we use the "str.replace" to remove the Writtenby

df['GENRE'] = df['GENRE'].str.replace("\n" , "")
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# 9995  Animation, Action, Adventure                 NaN
# 9996            Documentary, Sport                 NaN
# 9997     Adventure, Drama, Fantasy                 NaN
# 9998     Adventure, Drama, Fantasy                 NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df["GENRE"].mode()
# Out:
# 0    Comedy
# Name: GENRE, dtype: object

# %%
df["GENRE"].fillna("comedy", inplace = True)
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 NaN
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 NaN
# 9995  Animation, Action, Adventure                 NaN
# 9996            Documentary, Sport                 NaN
# 9997     Adventure, Drama, Fantasy                 NaN
# 9998     Adventure, Drama, Fantasy                 NaN
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# MOVIES           0
# GENRE            0
# RATING        1820
# ONE-LINE         0
# STARS            0
# VOTES         1820
# RunTime       2958
# Gross         9539
# START_YEAR       0
# END_YEAR         0
# dtype: int64

# %% [markdown]
# #### COLUMN RATING

# %%
df["RATING"]
# Out:
# 0       6.1
# 1       5.0
# 2       8.2
# 3       9.2
# 4       NaN
#        ...
# 9994    NaN
# 9995    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# Name: RATING, Length: 9999, dtype: float64

# %%
#We use linear interpolation cause we are dealing with numerical values and we assume the rate of change between the data points is constant
df['RATING'] = df['RATING'].interpolate(method='linear')
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS    VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN
# ...                                                 ...      ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...      NaN      NaN
# 9995                                                 \n      NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...      NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...      NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# MOVIES           0
# GENRE            0
# RATING           0
# ONE-LINE         0
# STARS            0
# VOTES         1820
# RunTime       2958
# Gross         9539
# START_YEAR       0
# END_YEAR         0
# dtype: int64

# %% [markdown]
# #### COLUMN VOTE

# %%
df["VOTES"]
# Out:
# 0        21,062
# 1        17,870
# 2       885,805
# 3       414,849
# 4           NaN
#          ...
# 9994        NaN
# 9995        NaN
# 9996        NaN
# 9997        NaN
# 9998        NaN
# Name: VOTES, Length: 9999, dtype: object

# %%
#we use the "str.replace" to remove the commas (,)
df['VOTES'] = df['VOTES'].str.replace("," , "")

#We convert our values to float
df['VOTES'] = df['VOTES'].astype(float)
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21062.0    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17870.0     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885805.0     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414849.0     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...       NaN      NaN
# ...                                                 ...       ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...       NaN      NaN
# 9995                                                 \n       NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...       NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...       NaN      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...       NaN      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
#We apply linear interpolation

df['VOTES'] = df['VOTES'].interpolate(method='linear')
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES  RunTime  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21062.0    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17870.0     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885805.0     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414849.0     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...  220353.5      NaN
# ...                                                 ...       ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...     433.0      NaN
# 9995                                                 \n     433.0      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...     433.0      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# MOVIES           0
# GENRE            0
# RATING           0
# ONE-LINE         0
# STARS            0
# VOTES            0
# RunTime       2958
# Gross         9539
# START_YEAR       0
# END_YEAR         0
# dtype: int64

# %% [markdown]
# #### COLUMN RUNTIME

# %%
#Renaming our column
df = df.rename(columns = {"RunTime":"RUNTIME"})
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES  RUNTIME  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21062.0    121.0
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17870.0     25.0
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885805.0     44.0
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414849.0     23.0
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...  220353.5      NaN
# ...                                                 ...       ...      ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...     433.0      NaN
# 9995                                                 \n     433.0      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...     433.0      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0      NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0      NaN
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df["RUNTIME"]
# Out:
# 0       121.0
# 1        25.0
# 2        44.0
# 3        23.0
# 4         NaN
#         ...
# 9994      NaN
# 9995      NaN
# 9996      NaN
# 9997      NaN
# 9998      NaN
# Name: RUNTIME, Length: 9999, dtype: float64

# %%
#We replace the Nan values by the mean runtime value
mean = df["RUNTIME"].mean()
mean
# Out:
# 68.68853855986366

# %%
df["RUNTIME"].fillna(mean, inplace = True)
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES     RUNTIME  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21062.0  121.000000
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17870.0   25.000000
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885805.0   44.000000
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414849.0   23.000000
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...  220353.5   68.688539
# ...                                                 ...       ...         ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...     433.0   68.688539
# 9995                                                 \n     433.0   68.688539
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...     433.0   68.688539
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0   68.688539
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0   68.688539
#
#      Gross START_YEAR END_YEAR
# 0      NaN       2021     2021
# 1      NaN       2021     2023
# 2      NaN       2010     2022
# 3      NaN       2013     2023
# 4      NaN       2021     2021
# ...    ...        ...      ...
# 9994   NaN       2021     2023
# 9995   NaN       2021     2023
# 9996   NaN       2022     2023
# 9997   NaN       2021     2023
# 9998   NaN       2021     2023
#
# [9999 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# MOVIES           0
# GENRE            0
# RATING           0
# ONE-LINE         0
# STARS            0
# VOTES            0
# RUNTIME          0
# Gross         9539
# START_YEAR       0
# END_YEAR         0
# dtype: int64

# %% [markdown]
# #### COLUMN GROSS

# %%
#As we can see, there are 9539 Nan values on the GROSS column, which is about 95% of the data,
#So we drop the column

df = df.drop(columns = "Gross")

# %%
df.isna().sum()
# Out:
# MOVIES        0
# GENRE         0
# RATING        0
# ONE-LINE      0
# STARS         0
# VOTES         0
# RUNTIME       0
# START_YEAR    0
# END_YEAR      0
# dtype: int64

# %% [markdown]
# ### Our data do not more contain Nan values

# %%
# checking for duplicated rows
df.duplicated().sum()
# Out:
# 20

# %% [markdown]
# #### There are 20 duplicated rows, so we shall keep only the first occurence of each duplicated row

# %%
df = df.drop_duplicates(keep='first')
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES     RUNTIME  \
# 0     \n    Director:\nPeter Thorwarth\n| \n    Star...   21062.0  121.000000
# 1     \n            \n    Stars:\nChris Wood, \nSara...   17870.0   25.000000
# 2     \n            \n    Stars:\nAndrew Lincoln, \n...  885805.0   44.000000
# 3     \n            \n    Stars:\nJustin Roiland, \n...  414849.0   23.000000
# 4     \n    Director:\nMatthias Schweighöfer\n| \n  ...  220353.5   68.688539
# ...                                                 ...       ...         ...
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...     433.0   68.688539
# 9995                                                 \n     433.0   68.688539
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...     433.0   68.688539
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0   68.688539
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...     433.0   68.688539
#
#      START_YEAR END_YEAR
# 0          2021     2021
# 1          2021     2023
# 2          2010     2022
# 3          2013     2023
# 4          2021     2021
# ...         ...      ...
# 9994       2021     2023
# 9995       2021     2023
# 9996       2022     2023
# 9997       2021     2023
# 9998       2021     2023
#
# [9979 rows x 9 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Our dataset is now clean with no Nan no Duplicated values

# %% [markdown]
# Now lets format some columns to be able to easily answer to some question
#
# e.g:  Who is the director of the film The imperfects? or
#
#     Which starts played in the film Heart of Arcane

# %% [markdown]
# #### COLUMN STARS

# %%
# Lets remove unneccessay characters 

df['STARS'] = df['STARS'].str.replace("\n" , "")
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES     RUNTIME  \
# 0         Director:Peter Thorwarth|     Stars:Peri B...   21062.0  121.000000
# 1                     Stars:Chris Wood, Sarah Michel...   17870.0   25.000000
# 2                     Stars:Andrew Lincoln, Norman R...  885805.0   44.000000
# 3                     Stars:Justin Roiland, Chris Pa...  414849.0   23.000000
# 4         Director:Matthias Schweighöfer|     Stars:...  220353.5   68.688539
# ...                                                 ...       ...         ...
# 9994                  Stars:Morgan Taylor Campbell, ...     433.0   68.688539
# 9995                                                        433.0   68.688539
# 9996      Director:Orlando von Einsiedel|     Star:P...     433.0   68.688539
# 9997      Director:Jovanka Vuckovic|     Stars:Morga...     433.0   68.688539
# 9998      Director:Jovanka Vuckovic|     Stars:Morga...     433.0   68.688539
#
#      START_YEAR END_YEAR
# 0          2021     2021
# 1          2021     2023
# 2          2010     2022
# 3          2013     2023
# 4          2021     2021
# ...         ...      ...
# 9994       2021     2023
# 9995       2021     2023
# 9996       2022     2023
# 9997       2021     2023
# 9998       2021     2023
#
# [9979 rows x 9 columns]

# %%
df['STARS']
# Out:
# 0           Director:Peter Thorwarth|     Stars:Peri B...
# 1                       Stars:Chris Wood, Sarah Michel...
# 2                       Stars:Andrew Lincoln, Norman R...
# 3                       Stars:Justin Roiland, Chris Pa...
# 4           Director:Matthias Schweighöfer|     Stars:...
#                               ...
# 9994                    Stars:Morgan Taylor Campbell, ...
# 9995
# 9996        Director:Orlando von Einsiedel|     Star:P...
# 9997        Director:Jovanka Vuckovic|     Stars:Morga...
# 9998        Director:Jovanka Vuckovic|     Stars:Morga...
# Name: STARS, Length: 9979, dtype: object

# %% [markdown]
# From the structure we can see that, We can see that, each function is Seperated by a |, so lets extract this function to easy answers to queries

# %%
def extract_names(stars):
   
    # Extract directors name
    directors = stars.str.extract('Director:(.*?)\|')
    
    # Extract stars na
    stars = stars.str.extract('Stars:(.*)')
    
    return directors, stars

# %%
# Obtaining the names of both the directors and the stars
directors, stars = extract_names(df['STARS'])

# Adding new Columns
df['DIRECTOR'] = directors
df['STAR'] = stars
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE  \
# 0     \nA woman with a mysterious illness is forced ...
# 1     \nThe war for Eternia begins again in what may...
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...
# 3     \nAn animated series that follows the exploits...
# 4     \nA prequel, set before the events of Army of ...
# ...                                                 ...
# 9994                                     \nAdd a Plot\n
# 9995                                     \nAdd a Plot\n
# 9996                                     \nAdd a Plot\n
# 9997                                     \nAdd a Plot\n
# 9998                                     \nAdd a Plot\n
#
#                                                   STARS     VOTES     RUNTIME  \
# 0         Director:Peter Thorwarth|     Stars:Peri B...   21062.0  121.000000
# 1                     Stars:Chris Wood, Sarah Michel...   17870.0   25.000000
# 2                     Stars:Andrew Lincoln, Norman R...  885805.0   44.000000
# 3                     Stars:Justin Roiland, Chris Pa...  414849.0   23.000000
# 4         Director:Matthias Schweighöfer|     Stars:...  220353.5   68.688539
# ...                                                 ...       ...         ...
# 9994                  Stars:Morgan Taylor Campbell, ...     433.0   68.688539
# 9995                                                        433.0   68.688539
# 9996      Director:Orlando von Einsiedel|     Star:P...     433.0   68.688539
# 9997      Director:Jovanka Vuckovic|     Stars:Morga...     433.0   68.688539
# 9998      Director:Jovanka Vuckovic|     Stars:Morga...     433.0   68.688539
#
#      START_YEAR END_YEAR               DIRECTOR  \
# 0          2021     2021        Peter Thorwarth
# 1          2021     2023                    NaN
# 2          2010     2022                    NaN
# 3          2013     2023                    NaN
# 4          2021     2021  Matthias Schweighöfer
# ...         ...      ...                    ...
# 9994       2021     2023                    NaN
# 9995       2021     2023                    NaN
# 9996       2022     2023  Orlando von Einsiedel
# 9997       2021     2023       Jovanka Vuckovic
# 9998       2021     2023       Jovanka Vuckovic
#
#                                                    STAR
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...
# ...                                                 ...
# 9994  Morgan Taylor Campbell, Chris Cope, Iñaki Godo...
# 9995                                                NaN
# 9996                                                NaN
# 9997  Morgan Taylor Campbell, Iñaki Godoy, Rhianna J...
# 9998  Morgan Taylor Campbell, Jennifer Cheon Garcia,...
#
# [9979 rows x 11 columns]

# %%
df = df.drop(columns = "STARS")
df = df.rename(columns = {"STAR": "STARS"})
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE     VOTES     RUNTIME  \
# 0     \nA woman with a mysterious illness is forced ...   21062.0  121.000000
# 1     \nThe war for Eternia begins again in what may...   17870.0   25.000000
# 2     \nSheriff Deputy Rick Grimes wakes up from a c...  885805.0   44.000000
# 3     \nAn animated series that follows the exploits...  414849.0   23.000000
# 4     \nA prequel, set before the events of Army of ...  220353.5   68.688539
# ...                                                 ...       ...         ...
# 9994                                     \nAdd a Plot\n     433.0   68.688539
# 9995                                     \nAdd a Plot\n     433.0   68.688539
# 9996                                     \nAdd a Plot\n     433.0   68.688539
# 9997                                     \nAdd a Plot\n     433.0   68.688539
# 9998                                     \nAdd a Plot\n     433.0   68.688539
#
#      START_YEAR END_YEAR               DIRECTOR  \
# 0          2021     2021        Peter Thorwarth
# 1          2021     2023                    NaN
# 2          2010     2022                    NaN
# 3          2013     2023                    NaN
# 4          2021     2021  Matthias Schweighöfer
# ...         ...      ...                    ...
# 9994       2021     2023                    NaN
# 9995       2021     2023                    NaN
# 9996       2022     2023  Orlando von Einsiedel
# 9997       2021     2023       Jovanka Vuckovic
# 9998       2021     2023       Jovanka Vuckovic
#
#                                                   STARS
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...
# ...                                                 ...
# 9994  Morgan Taylor Campbell, Chris Cope, Iñaki Godo...
# 9995                                                NaN
# 9996                                                NaN
# 9997  Morgan Taylor Campbell, Iñaki Godoy, Rhianna J...
# 9998  Morgan Taylor Campbell, Jennifer Cheon Garcia,...
#
# [9979 rows x 10 columns]

# %%
df.loc[df["STARS"] == Nan,
# Out:
# 0

# %% [markdown]
# We will just allow the Nan Values of these two new rows cause we don't have enough information to fill them.

# %% [markdown]
# #### COLUMN ONE-LINE

# %%
# Here we just remove characters that are not very neccessary 


df['ONE-LINE'] = df['ONE-LINE'].str.replace("\n" , "")
df
# Out:
#                                    MOVIES  \
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
#                                          GENRE  RATING  \
# 0         Action, Horror, Thriller                 6.1
# 1     Animation, Action, Adventure                 5.0
# 2          Drama, Horror, Thriller                 8.2
# 3     Animation, Adventure, Comedy                 9.2
# 4            Action, Crime, Horror                 8.4
# ...                                        ...     ...
# 9994     Adventure, Drama, Fantasy                 8.8
# 9995  Animation, Action, Adventure                 8.8
# 9996            Documentary, Sport                 8.8
# 9997     Adventure, Drama, Fantasy                 8.8
# 9998     Adventure, Drama, Fantasy                 8.8
#
#                                                ONE-LINE     VOTES     RUNTIME  \
# 0     A woman with a mysterious illness is forced in...   21062.0  121.000000
# 1     The war for Eternia begins again in what may b...   17870.0   25.000000
# 2     Sheriff Deputy Rick Grimes wakes up from a com...  885805.0   44.000000
# 3     An animated series that follows the exploits o...  414849.0   23.000000
# 4     A prequel, set before the events of Army of th...  220353.5   68.688539
# ...                                                 ...       ...         ...
# 9994                                         Add a Plot     433.0   68.688539
# 9995                                         Add a Plot     433.0   68.688539
# 9996                                         Add a Plot     433.0   68.688539
# 9997                                         Add a Plot     433.0   68.688539
# 9998                                         Add a Plot     433.0   68.688539
#
#      START_YEAR END_YEAR               DIRECTOR  \
# 0          2021     2021        Peter Thorwarth
# 1          2021     2023                    NaN
# 2          2010     2022                    NaN
# 3          2013     2023                    NaN
# 4          2021     2021  Matthias Schweighöfer
# ...         ...      ...                    ...
# 9994       2021     2023                    NaN
# 9995       2021     2023                    NaN
# 9996       2022     2023  Orlando von Einsiedel
# 9997       2021     2023       Jovanka Vuckovic
# 9998       2021     2023       Jovanka Vuckovic
#
#                                                   STARS
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...
# ...                                                 ...
# 9994  Morgan Taylor Campbell, Chris Cope, Iñaki Godo...
# 9995                                                NaN
# 9996                                                NaN
# 9997  Morgan Taylor Campbell, Iñaki Godoy, Rhianna J...
# 9998  Morgan Taylor Campbell, Jennifer Cheon Garcia,...
#
# [9979 rows x 10 columns]
